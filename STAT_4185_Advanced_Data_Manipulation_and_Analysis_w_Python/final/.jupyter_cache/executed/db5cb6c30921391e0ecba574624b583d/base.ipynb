# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 10
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/giovanni-lunetta/stat_4185/final':
  os.chdir(r'/Users/giovanni-lunetta/stat_4185/final')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# /var/folders/4b/z0w6x5_n59g_x_9s3qnbx_p80000gn/T/ipykernel_59830/1507729479.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/_bootstrap.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/_bootstrap_external.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/codecs.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/encodings/aliases.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/encodings/__init__.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/encodings/utf_8.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/abc.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/io.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/stat.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/_collections_abc.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/genericpath.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/posixpath.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/_sitebuiltins.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/_distutils_hack/__init__.py": 1648777944.5185397, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/types.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/warnings.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/__init__.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/_abc.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/keyword.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/operator.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/reprlib.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/collections/__init__.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/functools.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/util.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/importlib/machinery.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/enum.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/sre_constants.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/sre_parse.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/sre_compile.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/copyreg.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/re.py": 1648071154.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/_version.py": 1648779224.763216, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload/_json.cpython-310-darwin.so": 1648071408.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/scanner.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/decoder.py": 1648071155.0, "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/json/encoder.py": 1648071155.0, "/Libra ...

# %%
#| echo: true

import pandas as pd

df = pd.read_csv("/Users/giovanni-lunetta/stat_3255/stat_3255_final/data/cleaned.csv")

df.head(15)
# Out:
#            Created Date          Closed Date Agency
# 0   2023-01-31 22:33:56  2023-02-01 02:10:34   nypd  \
# 1   2023-01-31 22:33:50  2023-02-06 00:00:00    dob
# 2   2023-01-31 22:33:19  2023-02-01 18:55:00    dot
# 3   2023-01-31 22:33:17  2023-02-04 18:19:23   dsny
# 4   2023-01-31 22:33:11  2023-02-01 02:15:57   nypd
# 5   2023-01-31 22:33:11  2023-02-01 00:35:07   nypd
# 6   2023-01-31 22:33:09                  NaN    hpd
# 7   2023-01-31 22:33:09                  NaN    hpd
# 8   2023-01-31 22:33:09  2023-02-02 07:53:19    hpd
# 9   2023-01-31 22:33:01  2023-02-01 16:27:16    hpd
# 10  2023-01-31 22:32:57  2023-02-01 16:37:15    hpd
# 11  2023-01-31 22:32:55  2023-03-17 01:02:06    hpd
# 12  2023-01-31 22:32:51  2023-02-04 15:16:30   dsny
# 13  2023-01-31 22:32:45  2023-02-01 01:42:33   nypd
# 14  2023-01-31 22:32:43  2023-02-01 17:40:00    dot
#
#                    Complaint Type
# 0                 illegal parking  \
# 1   general construction/plumbing
# 2                street condition
# 3               missed collection
# 4                 illegal parking
# 5                           noise
# 6            unsanitary condition
# 7            unsanitary condition
# 8                  heat/hot water
# 9                  heat/hot water
# 10                 heat/hot water
# 11                       plumbing
# 12                    obstruction
# 13                illegal parking
# 14               street condition
#
#                                      Descriptor         Location Type
# 0                  commercial overnight parking       street/sidewalk  \
# 1                        building permit - none                 other
# 2                                       pothole                 other
# 3   recycling - paper/metal/glass/rigid plastic                street
# 4                 posted parking sign violation       street/sidewalk
# 5                              loud music/party   club/bar/restaurant
# 6                     garbage/recycling storage  residential building
# 7                     garbage/recycling storage  residential building
# 8                               entire building  residential building
# 9                               entire building  residential building
# 10                              entire building  residential building
# 11                                   basin/sink  residential building
# 12                                         cone                street
# 13                              blocked hydrant       street/sidewalk
# 14                                      pothole                 other
#
#     Incident Zip            Incident Address  Address Type
# 0        11361.0            34-49 200 street       address  \
# 1        10469.0           3001 grace avenue       address
# 2        11385.0         80-11 myrtle avenue       address
# 3        11413.0           139-15 225 street       address
# 4        11230.0         34 wellington court       address
# 5        11103.0       25-89 steinway street       address
# 6        11233.0            68 somers street       address
# 7        11233.0            68 somers street       address
# 8        10040.0        45 wadsworth terrace       address
# 9        11694.0  107-10 shore front parkway       address
# 10       10460.0           853 elsmere place       address
# 11       11207.0         350 snediker avenue       address
# 12       11427.0                  212 street  intersection
# 13       10461.0         1433 overing street       address
# 14       11379.0             62-15 69 street       address
#
#                    City  ... duration_hours duration_days day_of_week
# 0               bayside  ...       3.610556           0.0           1  \
# 1                 bronx  ...     121.436111           5.0           1
# 2             ridgewood  ...      20.361389           0.0           1
# 3   springfield gardens  ...      91.768333           3.0           1
# 4              brooklyn  ...       3.712778           0.0           1
# 5               astoria  ...       2.032222           0.0           1
# 6              brooklyn  ...     168.000000           NaN           1
# 7              brooklyn  ...     168.000000           NaN           1
# 8              new york  ...      33.336111           1.0           1
# 9          far rockaway  ...      17.904167           0.0           1
# 10                bronx  ...      18.071667           0.0           1
# 11             brooklyn  ...    1058.486389          44.0           1
# 12                  NaN  ...      88.727500           3.0           1
# 13                bronx  ...       3.163333           0.0           1
# 14       middle village  ...      19.121389           0.0           1
#
#    day_type housing_units  occupied_housing_units  median_home_value
# 0   weekday       11195.0                 10645.0           574200.0  \
# 1   weekday       24078.0                 22554.0           427100.0
# 2   weekday       37251.0                 34843.0           495800.0
# 3   weekday       12975.0                 12227.0           406200.0
# 4   weekday       34028.0                 30859.0           598000.0
# 5   weekday       18518.0                 16890.0           648900.0
# 6   weekday       29074.0                 25693.0           551900.0
# 7   weekday       29074.0                 25693.0           551900.0
# 8   weekday       16506.0                 15718.0           317300.0
# 9   weekday        9341.0                  8276.0           623200.0
# 10  weekday       20706.0                 19512.0           391700.0
# 11  weekday       34202.0                 31118.0           403800.0
# 12  weekday        7958.0                  7683.0           458400.0
# 13  weekday       21127.0                 19772.0           454700.0
# 14  weekday       14649.0                 13881.0           543800.0
#
#     population median_household_income  population_density
# 0      28606.0                 75335.0             16269.0
# 1      66631.0                 57776.0             26903.0
# 2      98592.0                 50799.0             27290.0
# 3      38912.0                 78667.0             12553.0
# 4      86408.0                 42170.0             46966.0
# 5      38780.0                 55129.0             54537.0
# 6      67053.0                 34492.0             49746.0
# 7      67053.0                 34492.0             49746.0
# 8      41905.0                 42721.0            111184.0
# 9      20408.0                 76944.0             14944.0
# 10     57311.0                 22307.0             43567.0
# 11     93386.0                 32945.0             34965.0
# 12     23593.0                 70108.0             14967.0
# 13     50502.0                 52347.0             21045.0
# 14     34821.0                 69843.0             16785.0
#
# [15 rows x 30 columns]

# %%
# import pandas and read in the csv file
import pandas as pd
df = pd.read_csv("nyc311_011523-012123_by022023.csv")

# %% [markdown]
# is there a statistically significant different between the total duration time between agencies?
#
# are the types of complaints statistically different between boroughs? between agencies?
#
# overall question: can we predict the borough that the 311 request came from?

# %%
# look at first few columns
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    56532399  01/15/2023 12:00:00 AM  01/17/2023 12:00:01 AM  DOHMH
# 1    56533302  01/15/2023 12:00:00 AM  01/23/2023 12:00:01 AM  DOHMH
# 2    56533451  01/15/2023 12:00:00 AM  01/17/2023 09:34:08 AM  DOHMH
# 3    56536021  01/15/2023 12:00:00 AM  01/17/2023 09:48:19 AM  DOHMH
# 4    56538004  01/15/2023 12:00:00 AM  01/23/2023 03:08:02 PM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 3  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 4  Department of Health and Mental Hygiene  Food Poisoning  3 or More
#
#                 Location Type  Incident Zip          Incident Address  ...  \
# 0  Restaurant/Bar/Deli/Bakery       11101.0      28-07 JACKSON AVENUE  ...
# 1       Other (Explain Below)       11101.0  48-18 NORTHERN BOULEVARD  ...
# 2            Food Cart Vendor       10305.0      1941 HYLAN BOULEVARD  ...
# 3  Restaurant/Bar/Deli/Bakery       11103.0     24-11 STEINWAY STREET  ...
# 4       Other (Explain Below)       10036.0              700 8 AVENUE  ...
#
#   Vehicle Type Taxi Company Borough Taxi Pick Up Location Bridge Highway Name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment   Latitude  \
# 0                      NaN       NaN                    NaN  40.748433
# 1                      NaN       NaN                    NaN  40.753619
# 2                      NaN       NaN                    NaN  40.582218
# 3                      NaN       NaN                    NaN  40.768674
# 4                      NaN       NaN                    NaN  40.758662
#
#    Longitude                                 Location
# 0 -73.938768  (40.74843329250923, -73.93876844606294)
# 1 -73.914245  (40.75361894380833, -73.91424532268624)
# 2 -74.097217  (40.58221767593629, -74.09721689751461)
# 3 -73.911074  (40.76867420855789, -73.91107425623979)
# 4 -73.988738  (40.75866221848322, -73.98873795996684)
#
# [5 rows x 41 columns]

# %% [markdown]
# Takeaways from first look:
# 1. Agency & Agency Name columns have same data?
# 2. Longitude, Latitude, and Location have same data?
# 3. Does Unique Key column provide us with any insight?
# 4. Why are there so many null values?

# %%
# explore possible duplicate columns 
check1 = df[['Agency', 'Agency Name']]
check1.head(20)
# Out:
#    Agency                                        Agency Name
# 0   DOHMH            Department of Health and Mental Hygiene
# 1   DOHMH            Department of Health and Mental Hygiene
# 2   DOHMH            Department of Health and Mental Hygiene
# 3   DOHMH            Department of Health and Mental Hygiene
# 4   DOHMH            Department of Health and Mental Hygiene
# 5    NYPD                    New York City Police Department
# 6    NYPD                    New York City Police Department
# 7    NYPD                    New York City Police Department
# 8    NYPD                    New York City Police Department
# 9    NYPD                    New York City Police Department
# 10   NYPD                    New York City Police Department
# 11   NYPD                    New York City Police Department
# 12   NYPD                    New York City Police Department
# 13   NYPD                    New York City Police Department
# 14   NYPD                    New York City Police Department
# 15   NYPD                    New York City Police Department
# 16   NYPD                    New York City Police Department
# 17    HPD  Department of Housing Preservation and Develop...
# 18    HPD  Department of Housing Preservation and Develop...
# 19    HPD  Department of Housing Preservation and Develop...

# %%
# explore possible duplicate columns 
check2 = df[['Longitude', 'Latitude', 'Location']]
check2.head(20)
# Out:
#     Longitude   Latitude                                  Location
# 0  -73.938768  40.748433   (40.74843329250923, -73.93876844606294)
# 1  -73.914245  40.753619   (40.75361894380833, -73.91424532268624)
# 2  -74.097217  40.582218   (40.58221767593629, -74.09721689751461)
# 3  -73.911074  40.768674   (40.76867420855789, -73.91107425623979)
# 4  -73.988738  40.758662   (40.75866221848322, -73.98873795996684)
# 5  -73.870409  40.863611    (40.8636112787934, -73.87040864262848)
# 6  -73.837580  40.702772   (40.70277200816068, -73.83758019372564)
# 7  -73.981921  40.687196   (40.68719608843765, -73.98192072171082)
# 8  -73.858906  40.832358   (40.83235751279932, -73.85890589915455)
# 9  -73.947833  40.773667  (40.773667438961155, -73.94783272698673)
# 10 -74.020238  40.635322  (40.635322144609006, -74.02023780744587)
# 11 -73.956854  40.581139   (40.58113905959043, -73.95685359548297)
# 12 -73.858286  40.738059   (40.73805858336545, -73.85828645464701)
# 13 -74.007961  40.624347   (40.62434723879337, -74.00796122481046)
# 14 -73.981921  40.687196   (40.68719608843765, -73.98192072171082)
# 15 -73.818608  40.702085   (40.70208492739425, -73.81860769369462)
# 16 -73.952562  40.576924   (40.57692409469654, -73.95256174864991)
# 17 -73.884451  40.744486   (40.74448582851266, -73.88445148292705)
# 18 -74.078557  40.642598  (40.642598225395105, -74.07855663279344)
# 19 -73.893170  40.699719  (40.699718970459095, -73.89317010236333)

# %%
# drop these columns from the dataset
df.drop(['Unique Key', 'Location', 'Agency Name'], axis=1, inplace=True)

# %% [markdown]
# One of the biggest issues with cleaning data are missing values:

# %%
# percent missing for each variable
print((df.isnull().sum() * 100)/ len(df))
# Out:
# Created Date                       0.000000
# Closed Date                        9.502653
# Agency                             0.000000
# Complaint Type                     0.000000
# Descriptor                         1.630285
# Location Type                     13.563678
# Incident Zip                       1.375094
# Incident Address                   4.743983
# Street Name                        4.743983
# Cross Street 1                    35.756118
# Cross Street 2                    35.756118
# Intersection Street 1             39.984211
# Intersection Street 2             39.910775
# Address Type                       0.756394
# City                               4.360278
# Landmark                          47.135068
# Facility Type                     99.478603
# Status                             0.000000
# Due Date                          99.809066
# Resolution Description             3.214673
# Resolution Action Updated Date     3.130221
# Community Board                    0.000000
# BBL                               11.428519
# Borough                            0.000000
# X Coordinate (State Plane)         1.788173
# Y Coordinate (State Plane)         1.731260
# Open Data Channel Type             0.000000
# Park Facility Name                 0.016523
# Park Borough                       0.000000
# Vehicle Type                      99.983477
# Taxi Company Borough              99.944923
# Taxi Pick Up Location             98.955369
# Bridge Highway Name               99.370284
# Bridge Highway Direction          99.671373
# Road Ramp                         99.752153
# Bridge Highway Segment            99.370284
# Latitude                           1.795517
# Longitude                          1.795517
# dtype: float64

# %%
# all of these columns have over 99% data missing, therefore, given the time contraint, it is not reasonable to try to fill this data in.
df.drop(['Bridge Highway Segment', 'Road Ramp', 'Bridge Highway Direction', 'Bridge Highway Name', 'Taxi Pick Up Location', 'Taxi Company Borough', 'Vehicle Type', 'Due Date', 'Facility Type'], axis=1, inplace=True)

# %% [markdown]
# More good practice is to check the descriptive statistics of our continuous variables:

# %%
df.describe()
# Out:
#        Incident Zip           BBL  X Coordinate (State Plane)  \
# count  53720.000000  4.824400e+04                5.349500e+04
# mean   10807.120514  2.695698e+09                1.005072e+06
# std      534.867544  1.148508e+09                2.094108e+04
# min    10000.000000  0.000000e+00                9.140500e+05
# 25%    10451.000000  2.027820e+09                9.934695e+05
# 50%    11201.000000  3.016035e+09                1.004174e+06
# 75%    11232.000000  4.000588e+09                1.017478e+06
# max    12345.000000  5.200430e+09                1.067177e+06
#
#        Y Coordinate (State Plane)      Latitude     Longitude
# count                53526.000000  53491.000000  53491.000000
# mean                207697.450342     40.736701    -73.924827
# std                  32076.816492      0.088046      0.075525
# min                 121152.000000     40.498949    -74.252452
# 25%                 183297.000000     40.669735    -73.966757
# 50%                 205608.500000     40.730943    -73.928097
# 75%                 237620.000000     40.818878    -73.880081
# max                 271730.000000     40.912468    -73.700743

# %%
# check where the zip code is 10000, and then remove these rows
count = df[df['Incident Zip'] == 10000.000000]['Incident Zip'].count()
print(count)
# Out:
# 23

# %%
df.drop(df[df['Incident Zip'] == 10000.000000].index, inplace=True)

# %% [markdown]
# What about more tedius problems?:

# %%
# view all unique values of 'Descriptor'
print(df["Descriptor"].value_counts(dropna=False))
# Out:
# ENTIRE BUILDING                5031
# Loud Music/Party               3839
# APARTMENT ONLY                 2651
# Blocked Hydrant                2647
# No Access                      2115
#                                ...
# Equipment Complaint               1
# Announcements                     1
# Bracket Arm Loose                 1
# Domestic Employee                 1
# Air: Odor, Nail Salon (AD8)       1
# Name: Descriptor, Length: 613, dtype: int64

# %%
# fill null values with 'Other'
df['Location Type'] = df['Location Type'].fillna('Other')

# change all 'Other (Explain Below)' to 'Other' because they are the same thing
df['Location Type'] = df['Location Type'].replace('Other (Explain Below)', 'Other')

# fill null values with 'Other'
df['Descriptor'] = df['Descriptor'].fillna('Other')

# change all versions of other to uniform 'Other'
df['Descriptor'] = df['Descriptor'].replace({'Other (Explain Below)': 'Other',
                                             'Other (complaint details)': 'Other',
                                             'Other/Unknown': 'Other'})

# %%
df["Address Type"].value_counts(dropna=False)
# Out:
# ADDRESS         49341
# INTERSECTION     3792
# BLOCKFACE         639
# NaN               412
# UNRECOGNIZED      201
# PLACENAME          61
# Name: Address Type, dtype: int64

# %%
# fill null values with 'UNRECOGNIZED'
df['Address Type'] = df['Address Type'].fillna('UNRECOGNIZED')

df["Address Type"].value_counts(dropna=False)
# Out:
# ADDRESS         49341
# INTERSECTION     3792
# BLOCKFACE         639
# UNRECOGNIZED      613
# PLACENAME          61
# Name: Address Type, dtype: int64

# %%
df['Park Facility Name'] = df['Park Facility Name'].fillna('Unspecified')

# %%
df["City"].value_counts(dropna=False)
# Out:
# BROOKLYN               16389
# BRONX                  11567
# NEW YORK                9967
# NaN                     2375
# STATEN ISLAND           2173
# JAMAICA                 1079
# ASTORIA                  921
# FLUSHING                 783
# QUEENS                   754
# RIDGEWOOD                673
# MANHATTAN                467
# FAR ROCKAWAY             454
# LONG ISLAND CITY         433
# WOODSIDE                 420
# FRESH MEADOWS            400
# CORONA                   379
# JACKSON HEIGHTS          349
# ELMHURST                 322
# SOUTH RICHMOND HILL      318
# OZONE PARK               317
# EAST ELMHURST            282
# MASPETH                  278
# HOWARD BEACH             277
# FOREST HILLS             232
# SOUTH OZONE PARK         220
# RICHMOND HILL            211
# MIDDLE VILLAGE           201
# WOODHAVEN                198
# REGO PARK                195
# BAYSIDE                  195
# QUEENS VILLAGE           193
# WHITESTONE               168
# COLLEGE POINT            160
# HOLLIS                   133
# SPRINGFIELD GARDENS      132
# SUNNYSIDE                129
# SAINT ALBANS             128
# KEW GARDENS              103
# OAKLAND GARDENS           90
# ROSEDALE                  82
# CAMBRIA HEIGHTS           80
# ARVERNE                   79
# LITTLE NECK               59
# BELLEROSE                 48
# GLEN OAKS                 12
# NEW HYDE PARK              9
# FLORAL PARK                5
# PELHAM                     2
# queens                     1
# Queens                     1
# BREEZY POINT               1
# Bronx                      1
# SPRING VALLEY              1
# Name: City, dtype: int64

# %%
# convert lowercase columni
df['City'] = df['City'].str.lower()

# %%
# percent missing for each variable
print((df.isnull().sum() * 100)/ len(df))
# Out:
# Created Date                       0.000000
# Closed Date                        9.484627
# Agency                             0.000000
# Complaint Type                     0.000000
# Descriptor                         0.000000
# Location Type                      0.000000
# Incident Zip                       1.375675
# Incident Address                   4.745987
# Street Name                        4.745987
# Cross Street 1                    35.769386
# Cross Street 2                    35.765713
# Intersection Street 1             39.995592
# Intersection Street 2             39.918451
# Address Type                       0.000000
# City                               4.362120
# Landmark                          47.149469
# Status                             0.000000
# Resolution Description             3.195827
# Resolution Action Updated Date     3.111340
# Community Board                    0.000000
# BBL                               11.403960
# Borough                            0.000000
# X Coordinate (State Plane)         1.788928
# Y Coordinate (State Plane)         1.731991
# Open Data Channel Type             0.000000
# Park Facility Name                 0.000000
# Park Borough                       0.000000
# Latitude                           1.796275
# Longitude                          1.796275
# dtype: float64

# %% [markdown]
# Now we get into the more interesting steps:

# %%
df['Resolution Action Updated Date'].value_counts(dropna=False)
# Out:
# 01/18/2023 12:00:00 AM    2576
# 01/17/2023 12:00:00 AM    2032
# 01/19/2023 12:00:00 AM    1942
# 01/20/2023 12:00:00 AM    1761
# NaN                       1694
#                           ...
# 01/17/2023 04:10:15 PM       1
# 01/17/2023 06:04:55 PM       1
# 01/17/2023 05:12:51 PM       1
# 01/17/2023 04:54:54 PM       1
# 01/23/2023 10:02:46 AM       1
# Name: Resolution Action Updated Date, Length: 29935, dtype: int64

# %%
df['Resolution Action Updated Date'] = pd.to_datetime(df['Resolution Action Updated Date'])

# %%
# Select the columns you want to print
two_columns_df = df[['Created Date', 'Closed Date']]

# Print the new dataframe with two columns
two_columns_df
# Out:
#                  Created Date             Closed Date
# 0      01/15/2023 12:00:00 AM  01/17/2023 12:00:01 AM
# 1      01/15/2023 12:00:00 AM  01/23/2023 12:00:01 AM
# 2      01/15/2023 12:00:00 AM  01/17/2023 09:34:08 AM
# 3      01/15/2023 12:00:00 AM  01/17/2023 09:48:19 AM
# 4      01/15/2023 12:00:00 AM  01/23/2023 03:08:02 PM
# ...                       ...                     ...
# 54464  01/22/2023 12:00:00 AM  01/22/2023 04:29:17 AM
# 54465  01/22/2023 12:00:00 AM  01/23/2023 10:03:08 AM
# 54466  01/22/2023 12:00:00 AM  01/23/2023 10:05:39 AM
# 54467  01/22/2023 12:00:00 AM  02/01/2023 12:00:01 AM
# 54468  01/22/2023 12:00:00 AM  01/23/2023 10:02:46 AM
#
# [54446 rows x 2 columns]

# %%
# convert "Created Date" and "Closed Date" columns to datetime objects
df['Created Date'] = pd.to_datetime(df['Created Date'])
df['Closed Date'] = pd.to_datetime(df['Closed Date'], errors='coerce')

# %%
# Select the columns you want to print
two_columns_df = df[['Created Date', 'Closed Date']]

# Print the new dataframe with two columns
two_columns_df
# Out:
#       Created Date         Closed Date
# 0       2023-01-15 2023-01-17 00:00:01
# 1       2023-01-15 2023-01-23 00:00:01
# 2       2023-01-15 2023-01-17 09:34:08
# 3       2023-01-15 2023-01-17 09:48:19
# 4       2023-01-15 2023-01-23 15:08:02
# ...            ...                 ...
# 54464   2023-01-22 2023-01-22 04:29:17
# 54465   2023-01-22 2023-01-23 10:03:08
# 54466   2023-01-22 2023-01-23 10:05:39
# 54467   2023-01-22 2023-02-01 00:00:01
# 54468   2023-01-22 2023-01-23 10:02:46
#
# [54446 rows x 2 columns]

# %%
# Check if there are any instances where the "Closed Date" is earlier than the "Created Date"
closed_earlier = df[df['Closed Date'] < df['Created Date']]

if closed_earlier.empty:
    print("No instances where 'Closed Date' is earlier than 'Created Date'")
else:
    print("There are instances where 'Closed Date' is earlier than 'Created Date'")
# Out:
# There are instances where 'Closed Date' is earlier than 'Created Date'

# %%
# prints the number of entries that have this problem
# prints the dataset to inspect further
print(len(closed_earlier))
closed_earlier
# Out:
# 134
#              Created Date         Closed Date Agency          Complaint Type  \
# 15759 2023-01-17 09:13:00 2023-01-16 09:12:00    DOT  Street Light Condition
# 16346 2023-01-17 10:14:00 2023-01-16 09:37:00    DOT  Street Light Condition
# 16374 2023-01-17 10:16:00 2023-01-16 10:15:00    DOT  Street Light Condition
# 16392 2023-01-17 10:18:00 2023-01-16 10:17:00    DOT  Street Light Condition
# 16544 2023-01-17 10:28:00 2023-01-16 10:27:00    DOT  Street Light Condition
# ...                   ...                 ...    ...                     ...
# 42922 2023-01-20 11:59:00 2023-01-19 11:58:00    DOT  Street Light Condition
# 43071 2023-01-20 12:02:00 2023-01-19 11:59:00    DOT  Street Light Condition
# 43073 2023-01-20 12:03:00 2023-01-19 12:02:00    DOT  Street Light Condition
# 43414 2023-01-20 12:47:00 2023-01-19 12:42:00    DOT  Street Light Condition
# 44095 2023-01-20 14:18:00 2023-01-13 14:18:00    DOT  Street Light Condition
#
#                               Descriptor Location Type  Incident Zip  \
# 15759        Fixture/Luminaire Door Open         Other       10470.0
# 16346                   Street Light Out         Other       10470.0
# 16374                   Street Light Out         Other       10470.0
# 16392  Fixture/Luminaire Out Of Position         Other       10459.0
# 16544          Fixture/Luminaire Hanging         Other       10457.0
# ...                                  ...           ...           ...
# 42922                   Street Light Out         Other       10461.0
# 43071                   Street Light Out         Other       10461.0
# 43073                   Street Light Out         Other       10475.0
# 43414            Street Light Dayburning         Other       11224.0
# 44095                   Street Light Out         Other       11238.0
#
#                 Incident Address                Street Name Cross Street 1  \
# 15759                        NaN                        NaN            NaN
# 16346                        NaN                        NaN            NaN
# 16374                        NaN                        NaN            NaN
# 16392                        NaN                        NaN            NaN
# 16544                        NaN                        NaN            NaN
# ...                          ...                        ...            ...
# 42922                        NaN                        NaN            NaN
# 43071                        NaN                        NaN            NaN
# 43073                        NaN                        NaN            NaN
# 43414  CONEY ISL BEACH BOARDWALK  CONEY ISL BEACH BOARDWALK            NaN
# 44095                        NaN                        NaN            NaN
#
#        ... Community Board BBL   Borough X Coordinate (State Plane)  \
# 15759  ...        12 BRONX NaN     BRONX                  1026374.0
# 16346  ...        12 BRONX NaN     BRONX                  1025621.0
# 16374  ...        12 BRONX NaN     BRONX                  1024368.0
# 16392  ...        03 BRONX NaN     BRONX                  1014492.0
# 16544  ...        06 BRONX NaN     BRONX                  1015598.0
# ...    ...             ...  ..       ...                        ...
# 42922  ...        11 BRONX NaN     BRONX                  1028773.0
# 43071  ...        10 BRONX NaN     BRONX                  1031720.0
# 43073  ...        10 BRONX NaN     BRONX                  1032818.0
# 43414  ...     13 BROOKLYN NaN  BROOKLYN                   983593.0
# 44095  ...     08 BROOKLYN NaN  BROOKLYN                   993280.0
#
#       Y Coordinate (State Plane) Open Data Channel Type Park Facility Name  \
# 15759                   267996.0                UNKNOWN        Unspecified
# 16346                   268476.0                UNKNOWN        Unspecified
# 16374                   267516.0                UNKNOWN        Unspecified
# 16392                   242563.0                UNKNOWN        Unspecified
# 16544                   247912.0                UNKNOWN        Unspecified
# ...                          ...                    ...                ...
# 42922                   246156.0                UNKNOWN        Unspecified
# 43071                   245301.0                UNKNOWN        Unspecified
# 43073                   257638.0                UNKNOWN        Unspecified
# 43414                   147787.0                UNKNOWN        Unspecified
# 44095                   184460.0                UNKNOWN        Unspecified
#
#       Park Borough   Latitude  Longitude
# 15759        BRONX  40.902160 -73.847620
# 16346        BRONX  40.903481 -73.850341
# 16374        BRONX  40.900852 -73.854879
# 16392        BRONX  40.832403 -73.890717
# 16544        BRONX  40.847081 -73.886695
# ...            ...        ...        ...
# 42922        BRONX  40.842204 -73.839087
# 43071        BRONX  40.839842 -73.828442
# 43073        BRONX  40.873698 -73.824384
# 43414     BROOKLYN  40.572317 -74.002365
# 44095     BROOKLYN  40.672972 -73.967447
#
# [134 rows x 29 columns]

# %%
# creates an index containing all of examples where closed date is before created data and drops those columns
index_to_drop = df.index[df['Closed Date'] < df['Created Date']].tolist()
df.drop(index_to_drop, inplace=True)

# %% [markdown]
# Now its time for geocoding

# %%
print((df.isnull().sum() * 100)/ len(df))
# Out:
# Created Date                       0.000000
# Closed Date                        9.508028
# Agency                             0.000000
# Complaint Type                     0.000000
# Descriptor                         0.000000
# Location Type                      0.000000
# Incident Zip                       1.347768
# Incident Address                   4.625129
# Street Name                        4.625129
# Cross Street 1                    35.667992
# Cross Street 2                    35.642215
# Intersection Street 1             40.037193
# Intersection Street 2             39.959862
# Address Type                       0.000000
# City                               4.341582
# Landmark                          47.019075
# Status                             0.000000
# Resolution Description             3.203712
# Resolution Action Updated Date     3.119016
# Community Board                    0.000000
# BBL                               11.216674
# Borough                            0.000000
# X Coordinate (State Plane)         1.762042
# Y Coordinate (State Plane)         1.704964
# Open Data Channel Type             0.000000
# Park Facility Name                 0.000000
# Park Borough                       0.000000
# Latitude                           1.769406
# Longitude                          1.769406
# dtype: float64

# %%
# import geopy
# import geocoder
# import pandas as pd

# # create a function to perform geocoding
# def geocode(address):
#     try:
#         location = geocoder.osm(address)
#         return location.lat, location.lng
#     except:
#         return None, None

# # create a function to perform reverse geocoding
# def reverse_geocode(latitude, longitude):
#     try:
#         location = geopy.Point(latitude, longitude)
#         address = geopy.geocoders.Nominatim(user_agent="my-application").reverse(location)
#         return address.address
#     except:
#         return None

# # iterate over the DataFrame and fill in the missing values
# for index, row in df.iterrows():
#     if pd.isnull(row['Latitude']) or pd.isnull(row['Longitude']):
#         lat, lng = geocode(row['Incident Address'])
#         df.at[index, 'Latitude'] = lat
#         df.at[index, 'Longitude'] = lng
#     if pd.isnull(row['Incident Address']):
#         address = reverse_geocode(row['Latitude'], row['Longitude'])
#         df.at[index, 'Incident Address'] = address

# # percent missing for each variable
# print((df.isnull().sum() * 100)/ len(df))
# Out:
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Status code Unknown from https://nominatim.openstreetmap.org/search: ERROR - HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5.0)
# Created Date                       0.000000
# Closed Date                        9.508028
# Agency                             0.000000
# Complaint Type                     0.000000
# Descriptor                         0.000000
# Location Type                      0.000000
# Incident Zip                       1.347768
# Incident Address                   4.625129
# Street Name                        4.625129
# Cross Street 1                    35.667992
# Cross Street 2                    35.642215
# Intersection Street 1             40.037193
# Intersection Street 2             39.959862
# Address Type                       0.000000
# City                               4.341582
# Landmark                          47.019075
# Status                             0.000000
# Resolution Description             3.203712
# Resolution Action Updated Date     3.119016
# Community Board                    0.000000
# BBL                               11.216674
# Borough                            0.000000
# X Coordinate (State Plane)         1.762042
# Y Coordinate (State Plane)         1.704964
# Open Data Channel Type             0.000000
# Park Facility Name                 0.000000
# Park Borough                       0.000000
# Latitude                           0.101267
# Longitude                          0.101267
# dtype: float64

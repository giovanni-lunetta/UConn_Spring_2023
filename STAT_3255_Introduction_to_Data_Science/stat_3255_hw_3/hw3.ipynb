# %% [markdown]
# 1. Use the filter from the website to download the crash data of January 2023; save it under a directory data with an informative name (e.g., nyc_crashes_202301.csv).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("nyc_crashes_202301.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6684 entries, 0 to 6683
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     6684 non-null   object
#  1   CRASH TIME                     6684 non-null   object
#  2   BOROUGH                        4414 non-null   object
#  3   ZIP CODE                       4414 non-null   float64
#  4   LATITUDE                       6236 non-null   float64
#  5   LONGITUDE                      6236 non-null   float64
#  6   LOCATION                       6236 non-null   object
#  7   ON STREET NAME                 4949 non-null   object
#  8   CROSS STREET NAME              3195 non-null   object
#  9   OFF STREET NAME                1735 non-null   object
#  10  NUMBER OF PERSONS INJURED      6684 non-null   int64
#  11  NUMBER OF PERSONS KILLED       6684 non-null   int64
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 2. Get basic summaries of each variable: missing percentage; descriptive statistics for continuous variables; frequency tables for discrete variables.

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  01/02/2023      18:00     NaN       NaN  40.654440 -73.890810
# 1  01/02/2023      23:51     NaN       NaN        NaN        NaN
# 2  01/02/2023      13:00  QUEENS   11368.0  40.741104 -73.853820
# 3  01/02/2023       6:17     NaN       NaN  40.602543 -74.133250
# 4  01/02/2023       1:50     NaN       NaN  40.756897 -73.893196
#
#                   LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0    (40.65444, -73.89081)   WORTMAN AVENUE               NaN
# 1                      NaN     BELT PARKWAY               NaN
# 2   (40.741104, -73.85382)  VANCLEEF STREET        108 STREET
# 3   (40.602543, -74.13325)              NaN               NaN
# 4  (40.756897, -73.893196)        32 AVENUE               NaN
#
#              OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                        NaN  ...                    Unspecified
# 1                        NaN  ...                    Unspecified
# ...

# %%
df.describe(include = 'all')
# Out:
#         CRASH DATE CRASH TIME   BOROUGH      ZIP CODE     LATITUDE  \
# count         6684       6684      4414   4414.000000  6236.000000
# unique          30       1221         5           NaN          NaN
# top     01/13/2023       0:00  BROOKLYN           NaN          NaN
# freq           292        104      1557           NaN          NaN
# mean           NaN        NaN       NaN  10901.618487    40.224414
# std            NaN        NaN       NaN    522.774719     4.469021
# min            NaN        NaN       NaN  10001.000000     0.000000
# 25%            NaN        NaN       NaN  10457.000000    40.661631
# 50%            NaN        NaN       NaN  11209.000000    40.710435
# 75%            NaN        NaN       NaN  11238.000000    40.771128
# max            NaN        NaN       NaN  11694.000000    40.912827
#
#           LONGITUDE    LOCATION ON STREET NAME CROSS STREET NAME  \
# count   6236.000000        6236           4949              3195
# ...

# %%
df[["BOROUGH", "ZIP CODE", "LONGITUDE", "LATITUDE"]]
# Out:
#        BOROUGH  ZIP CODE  LONGITUDE   LATITUDE
# 0          NaN       NaN -73.890810  40.654440
# 1          NaN       NaN        NaN        NaN
# 2       QUEENS   11368.0 -73.853820  40.741104
# 3          NaN       NaN -74.133250  40.602543
# 4          NaN       NaN -73.893196  40.756897
# ...        ...       ...        ...        ...
# 6679       NaN       NaN -73.881050  40.828430
# 6680       NaN       NaN -73.961880  40.699930
# 6681       NaN       NaN -73.839800  40.693657
# 6682  BROOKLYN   11204.0 -73.985700  40.620130
# 6683       NaN       NaN   0.000000   0.000000
#
# [6684 rows x 4 columns]

# %%
# one large frequency table

discrete_vars = df.select_dtypes(include=['object']).columns

# create frequency tables
for col in discrete_vars:
    print("\nFrequency table for column '{}':".format(col))
    print(df[col].value_counts(normalize=True))
# Out:
# Frequency table for column 'CRASH DATE':
# 01/13/2023    0.043686
# 01/19/2023    0.041592
# 01/12/2023    0.040096
# 01/17/2023    0.037253
# 01/10/2023    0.037104
# 01/04/2023    0.036655
# 01/18/2023    0.036206
# 01/23/2023    0.035907
# 01/14/2023    0.035159
# 01/25/2023    0.035009
# 01/09/2023    0.034560
# 01/05/2023    0.034261
# 01/26/2023    0.033962
# 01/22/2023    0.033812
# 01/06/2023    0.033812
# 01/20/2023    0.033662
# 01/28/2023    0.033214
# 01/21/2023    0.032615
# 01/24/2023    0.032466
# 01/03/2023    0.032017
# 01/16/2023    0.032017
# 01/11/2023    0.031718
# 01/27/2023    0.030072
# 01/02/2023    0.029324
# 01/31/2023    0.028725
# 01/15/2023    0.028276
# 01/30/2023    0.027828
# 01/08/2023    0.027379
# 01/07/2023    0.025883
# 01/29/2023    0.025733
# Name: CRASH DATE, dtype: float64
#
# Frequency table for column 'CRASH TIME':
# 0:00     0.015560
# 15:00    0.010772
# 18:00    0.010323
# 17:00    0.009725
# 10:00    0.009276
#            ...
# ...

# %%
# individually

print(df["CRASH DATE"].value_counts(dropna=False))
# Out:
# 01/13/2023    292
# 01/19/2023    278
# 01/12/2023    268
# 01/17/2023    249
# 01/10/2023    248
# 01/04/2023    245
# 01/18/2023    242
# 01/23/2023    240
# 01/14/2023    235
# 01/25/2023    234
# 01/09/2023    231
# 01/05/2023    229
# 01/26/2023    227
# 01/22/2023    226
# 01/06/2023    226
# 01/20/2023    225
# 01/28/2023    222
# 01/21/2023    218
# 01/24/2023    217
# 01/03/2023    214
# 01/16/2023    214
# 01/11/2023    212
# 01/27/2023    201
# 01/02/2023    196
# 01/31/2023    192
# 01/15/2023    189
# 01/30/2023    186
# 01/08/2023    183
# 01/07/2023    173
# 01/29/2023    172
# Name: CRASH DATE, dtype: int64

# %%
print(df["CRASH TIME"].value_counts(dropna=False))
# Out:
# 0:00     104
# 15:00     72
# 18:00     69
# 17:00     65
# 10:00     62
#         ...
# 8:23       1
# 9:27       1
# 14:47      1
# 4:16       1
# 3:57       1
# Name: CRASH TIME, Length: 1221, dtype: int64

# %%
print(df["BOROUGH"].value_counts(dropna=False))
# Out:
# NaN              2270
# BROOKLYN         1557
# QUEENS           1209
# BRONX             743
# MANHATTAN         721
# STATEN ISLAND     184
# Name: BOROUGH, dtype: int64

# %%
print(df["LOCATION"].value_counts(dropna=False))
# Out:
# NaN                        448
# (0.0, 0.0)                  76
# (40.651863, -73.86536)       6
# (40.748913, -73.9374)        6
# (40.861862, -73.91275)       5
#                           ...
# (40.761745, -73.81353)       1
# (40.814266, -73.912964)      1
# (40.846424, -73.86034)       1
# (40.675434, -73.97797)       1
# (40.62013, -73.9857)         1
# Name: LOCATION, Length: 5452, dtype: int64

# %%
print(df["ON STREET NAME"].value_counts(dropna=False))
# Out:
# NaN                           1735
# BELT PARKWAY                   117
# LONG ISLAND EXPRESSWAY          70
# BROOKLYN QUEENS EXPRESSWAY      66
# FDR DRIVE                       51
#                               ...
# 19 ROAD                          1
# QUINCE AVENUE                    1
# ROSEWOOD STREET                  1
# SHEEPSHEAD BAY ROAD              1
# ASCAN AVENUE                     1
# Name: ON STREET NAME, Length: 1505, dtype: int64

# %%
print(df["CROSS STREET NAME"].value_counts(dropna=False))
# Out:
# NaN                  3489
# 3 AVENUE               37
# BROADWAY               32
# 2 AVENUE               30
# ATLANTIC AVENUE        23
#                      ...
# WEST SERVICE ROAD       1
# WEST 81 STREET          1
# 167 STREET              1
# BAY VIEW PLACE          1
# 113 AVENUE              1
# Name: CROSS STREET NAME, Length: 1489, dtype: int64

# %%
print(df["OFF STREET NAME"].value_counts(dropna=False))
# Out:
# NaN                              4949
# 985       RICHMOND AVENUE           3
# 49-21     METROPOLITAN AVENUE       3
# 560       WINTHROP STREET           3
# ATLANTIC AVENUE                     3
#                                  ...
# 1707      EAST 14 STREET            1
# 42-36     201 STREET                1
# 1595      FULTON STREET             1
# 2951      WEST 8 STREET             1
# 102       STRYKER STREET            1
# Name: OFF STREET NAME, Length: 1715, dtype: int64

# %%
print(df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts(dropna=False))
# Out:
# Driver Inattention/Distraction                           1631
# Unspecified                                              1567
# Failure to Yield Right-of-Way                             529
# Following Too Closely                                     418
# Passing or Lane Usage Improper                            320
# Unsafe Speed                                              261
# Passing Too Closely                                       246
# Backing Unsafely                                          206
# Traffic Control Disregarded                               185
# Turning Improperly                                        177
# Other Vehicular                                           174
# Driver Inexperience                                       141
# Unsafe Lane Changing                                      117
# Alcohol Involvement                                       109
# View Obstructed/Limited                                    69
# ...

# %%
print(df["CONTRIBUTING FACTOR VEHICLE 2"].value_counts(dropna=False))
# Out:
# Unspecified                                              4205
# NaN                                                      1713
# Driver Inattention/Distraction                            291
# Other Vehicular                                            86
# Following Too Closely                                      67
# Passing or Lane Usage Improper                             54
# Traffic Control Disregarded                                45
# Failure to Yield Right-of-Way                              36
# Passing Too Closely                                        28
# Unsafe Speed                                               24
# Driver Inexperience                                        21
# Backing Unsafely                                           17
# View Obstructed/Limited                                    16
# Reaction to Uninvolved Vehicle                             12
# Aggressive Driving/Road Rage                               12
# ...

# %%
print(df["CONTRIBUTING FACTOR VEHICLE 3"].value_counts(dropna=False))
# Out:
# NaN                               6062
# Unspecified                        576
# Other Vehicular                     17
# Following Too Closely               12
# Driver Inattention/Distraction       8
# Passing or Lane Usage Improper       2
# Obstruction/Debris                   1
# Unsafe Speed                         1
# Passing Too Closely                  1
# View Obstructed/Limited              1
# Pavement Slippery                    1
# Turning Improperly                   1
# Reaction to Uninvolved Vehicle       1
# Name: CONTRIBUTING FACTOR VEHICLE 3, dtype: int64

# %%
print(df["CONTRIBUTING FACTOR VEHICLE 4"].value_counts(dropna=False))
# Out:
# NaN                               6513
# Unspecified                        163
# Other Vehicular                      4
# Following Too Closely                2
# Obstruction/Debris                   1
# Passing or Lane Usage Improper       1
# Name: CONTRIBUTING FACTOR VEHICLE 4, dtype: int64

# %%
print(df["CONTRIBUTING FACTOR VEHICLE 5"].value_counts(dropna=False))
# Out:
# NaN                   6631
# Unspecified             51
# Obstruction/Debris       1
# Other Vehicular          1
# Name: CONTRIBUTING FACTOR VEHICLE 5, dtype: int64

# %%
print(df["VEHICLE TYPE CODE 1"].value_counts(dropna=False))
# Out:
# Sedan                                  3199
# Station Wagon/Sport Utility Vehicle    2303
# Taxi                                    166
# Pick-up Truck                           154
# Bus                                     132
#                                        ...
# UTIL                                      1
# ELECTRIC S                                1
# VAn                                       1
# Motorized                                 1
# FDNY AMBUL                                1
# Name: VEHICLE TYPE CODE 1, Length: 62, dtype: int64

# %%
print(df["VEHICLE TYPE CODE 2"].value_counts(dropna=False))
# Out:
# NaN                                    2463
# Sedan                                  1804
# Station Wagon/Sport Utility Vehicle    1325
# Bike                                    178
# Box Truck                               148
#                                        ...
# FOGLIFT                                   1
# School bus                                1
# FORKLIFT                                  1
# NYC AMBULA                                1
# wheelchair                                1
# Name: VEHICLE TYPE CODE 2, Length: 76, dtype: int64

# %%
print(df["VEHICLE TYPE CODE 3"].value_counts(dropna=False))
# Out:
# NaN                                    6110
# Sedan                                   296
# Station Wagon/Sport Utility Vehicle     231
# Pick-up Truck                            15
# Box Truck                                 5
# Van                                       5
# Tractor Truck Diesel                      4
# Bus                                       3
# Taxi                                      3
# Convertible                               2
# Flat Bed                                  2
# Moped                                     2
# UTILITY TR                                1
# Carry All                                 1
# Tractor Truck Gasoline                    1
# Tow Truck / Wrecker                       1
# FLAT                                      1
# Bike                                      1
# Name: VEHICLE TYPE CODE 3, dtype: int64

# %%
print(df["VEHICLE TYPE CODE 4"].value_counts(dropna=False))
# Out:
# NaN                                    6525
# Sedan                                    78
# Station Wagon/Sport Utility Vehicle      66
# Pick-up Truck                             7
# Tractor Truck Diesel                      2
# Dump                                      1
# Flat Bed                                  1
# SEMI-TRUCK                                1
# Convertible                               1
# 4 dr sedan                                1
# PK                                        1
# Name: VEHICLE TYPE CODE 4, dtype: int64

# %%
print(df["VEHICLE TYPE CODE 5"].value_counts(dropna=False))
# Out:
# NaN                                    6633
# Station Wagon/Sport Utility Vehicle      27
# Sedan                                    21
# Pick-up Truck                             1
# Box Truck                                 1
# Taxi                                      1
# Name: VEHICLE TYPE CODE 5, dtype: int64

# %%
# total counts of null

missing_count = df.isnull().sum()
missing_count
# Out:
# CRASH DATE                          0
# CRASH TIME                          0
# BOROUGH                          2270
# ZIP CODE                         2270
# LATITUDE                          448
# LONGITUDE                         448
# LOCATION                          448
# ON STREET NAME                   1735
# CROSS STREET NAME                3489
# OFF STREET NAME                  4949
# NUMBER OF PERSONS INJURED           0
# NUMBER OF PERSONS KILLED            0
# NUMBER OF PEDESTRIANS INJURED       0
# NUMBER OF PEDESTRIANS KILLED        0
# NUMBER OF CYCLIST INJURED           0
# NUMBER OF CYCLIST KILLED            0
# NUMBER OF MOTORIST INJURED          0
# NUMBER OF MOTORIST KILLED           0
# CONTRIBUTING FACTOR VEHICLE 1      51
# CONTRIBUTING FACTOR VEHICLE 2    1713
# CONTRIBUTING FACTOR VEHICLE 3    6062
# CONTRIBUTING FACTOR VEHICLE 4    6513
# CONTRIBUTING FACTOR VEHICLE 5    6631
# COLLISION_ID                        0
# VEHICLE TYPE CODE 1               125
# ...

# %%
# percentage of null counts

percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# CRASH DATE                        0.000000
# CRASH TIME                        0.000000
# BOROUGH                          33.961700
# ZIP CODE                         33.961700
# LATITUDE                          6.702573
# LONGITUDE                         6.702573
# LOCATION                          6.702573
# ON STREET NAME                   25.957510
# CROSS STREET NAME                52.199282
# OFF STREET NAME                  74.042490
# NUMBER OF PERSONS INJURED         0.000000
# NUMBER OF PERSONS KILLED          0.000000
# NUMBER OF PEDESTRIANS INJURED     0.000000
# NUMBER OF PEDESTRIANS KILLED      0.000000
# NUMBER OF CYCLIST INJURED         0.000000
# NUMBER OF CYCLIST KILLED          0.000000
# NUMBER OF MOTORIST INJURED        0.000000
# NUMBER OF MOTORIST KILLED         0.000000
# CONTRIBUTING FACTOR VEHICLE 1     0.763016
# CONTRIBUTING FACTOR VEHICLE 2    25.628366
# CONTRIBUTING FACTOR VEHICLE 3    90.694195
# CONTRIBUTING FACTOR VEHICLE 4    97.441652
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 3. Are the LATITUDE and LONGITIDE values all look legitimate? If not (e.g., zeroes), code them as missing values.

# %%
# replaces the value 0.000000 with missing value
df["LONGITUDE"].replace(0.000000, np.nan, inplace=True)
df["LATITUDE"].replace(0.000000, np.nan, inplace=True)

df.describe()
# Out:
#            ZIP CODE     LATITUDE    LONGITUDE  NUMBER OF PERSONS INJURED  \
# count   4414.000000  6160.000000  6160.000000                6684.000000
# mean   10901.618487    40.720689   -73.918421                   0.504039
# std      522.774719     0.081507     0.086311                   0.812230
# min    10001.000000    40.504658   -74.250150                   0.000000
# 25%    10457.000000    40.663970   -73.966190                   0.000000
# 50%    11209.000000    40.711383   -73.923108                   0.000000
# 75%    11238.000000    40.772722   -73.866734                   1.000000
# max    11694.000000    40.912827   -73.705800                  21.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count               6684.000000                    6684.000000
# mean                   0.002394                       0.117145
# std                    0.051843                       0.403723
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 4. If OFF STREET NAME is not missing, are there any missing LATITUDE and LONGITUDE? If so, geocode the addresses.

# %%
# creates a boolean mask to select only the rows where "OFF STREET NAME" is not missing
mask = df["OFF STREET NAME"].notnull()

# check if any of the "LATITUDE" and "LONGITUDE" values are missing
if df[mask][["LATITUDE", "LONGITUDE"]].isnull().any().any():
    print("There are missing values for LATITUDE and/or LONGITUDE.")
else:
    print("There are no missing values for LATITUDE and LONGITUDE.")
# Out:
# There are missing values for LATITUDE and/or LONGITUDE.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 5. (Optional) Are the missing patterns of ON STREET NAME and LATITUDE" the same? Summarize the missing patterns by a cross table. If ON STREET NAME and CROSS STREET NAME are available, use geocoding by intersection to fill the LATITUDE and LONGITUDE`.

# %%
# you could do it this way

# create a cross table of the missing patterns of "ON STREET NAME" and "LATITUDE"
pd.crosstab(index = df['ON STREET NAME'],
        columns = df['LATITUDE'], dropna = False)
# Out:
# LATITUDE               40.504658  40.507750  40.512450  40.515236  40.515926  \
# ON STREET NAME
# 1 AVENUE                       0          0          0          0          0
# 1 STREET                       0          0          0          0          0
# 10 AVENUE                      0          0          0          0          0
# 100 STREET                     0          0          0          0          0
# 101 AVENUE                     0          0          0          0          0
# ...                          ...        ...        ...        ...        ...
# WYONA STREET                   0          0          0          0          0
# YATES AVENUE                   0          0          0          0          0
# YELLOWSTONE BOULEVARD          0          0          0          0          0
# YORK AVENUE                    0          0          0          0          0
# YORK STREET                    0          0          0          0          0
#
# ...

# %%
# but this way is better to visualize

# create a binary missingness indicator for "ON STREET NAME" and "LATITUDE"
# 1 is missing 0 is not missing
df['ON STREET NAME Missing'] = df['ON STREET NAME'].isna().astype(int)
df['LATITUDE Missing'] = df['LATITUDE'].isna().astype(int)

# create a cross table of the missing patterns of "ON STREET NAME" and "LATITUDE"
pd.crosstab(index = df['ON STREET NAME Missing'],
        columns = df['LATITUDE Missing'], dropna = False)
# Out:
# LATITUDE Missing           0    1
# ON STREET NAME Missing
# 0                       4478  471
# 1                       1682   53

# %%
ct = pd.crosstab(df['ON STREET NAME Missing'], df['LATITUDE Missing'])

# check if the missing patterns are the same
if (ct.loc[0,0] == ct.loc[1,1]) & (ct.loc[0,1] == ct.loc[1,0]):
    print("The missing patterns are the same.")
else:
    print("The missing patterns are not the same.")
# Out:
# The missing patterns are not the same.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 6. Are ZIP CODE and BOROUGH always missing together? If LATITUDE and LONGITUDE are available, use reverse geocoding to fill the ZIP CODE and BOROUGH.

# %%
# create a binary missingness indicator for "ZIP CODE" and "BOROUGH"
# 1 is missing 0 is not missing
df['ZIP CODE Missing'] = df['ZIP CODE'].isna().astype(int)
df['BOROUGH Missing'] = df['BOROUGH'].isna().astype(int)

# create a cross table of the missing patterns of "ZIP CODE" and "BOROUGH"
pd.crosstab(df['ZIP CODE Missing'], df['BOROUGH Missing'])
# Out:
# BOROUGH Missing      0     1
# ZIP CODE Missing
# 0                 4414     0
# 1                    0  2270

# %%
# create a cross table of the missing patterns of "ZIP CODE" and "BOROUGH"
ct = pd.crosstab(df['ZIP CODE Missing'], df['BOROUGH Missing'])

# check if the missing patterns are the same
if (ct.loc[0,0] == ct.loc[1,1]) & (ct.loc[0,1] == ct.loc[1,0]):
    print("The missing patterns are the same.")
else:
    print("The missing patterns are not the same.")
# Out:
# The missing patterns are not the same.

# %%
# used same function from STAT3255 notes

from uszipcode import SearchEngine

sr = SearchEngine()

def nyczip2burough(zip):
    nzip = int(zip)
    if nzip >= 10001 and nzip <= 10282:
        return "MANHATTAN"
    elif nzip >= 10301 and nzip <= 10314:
        return "STATEN ISLAND"
    elif nzip >= 10451 and nzip <= 10475:
        return "BRONX"
    elif nzip >= 11004 and nzip <= 11109:
        return "QUEENS"
    elif nzip >= 11351 and nzip <= 11697:
        return "QUEENS"
    elif nzip >= 11201 and nzip <= 11256:
        return "BROOKLYN"
    else:
        return np.nan

# %%
# loop through each row in the dataframe
for index, row in df.iterrows():
    
    # check if either ZIP CODE or BOROUGH is missing
    if pd.isnull(row["ZIP CODE"]) or pd.isnull(row["BOROUGH"]):
        
        # check if both LATITUDE and LONGITUDE are available
        if not pd.isnull(row["LATITUDE"]) and not pd.isnull(row["LONGITUDE"]):
            
            # use reverse geocoding to get the zip code and borough
            result = sr.by_coordinates(row["LATITUDE"], row["LONGITUDE"], radius=1, returns=1)
            
            # check if the result is not empty
            if result:
                
                # get the zip code and borough
                zipcode = result[0].zipcode
                borough = nyczip2burough(zipcode)
                
                # update the missing ZIP CODE and BOROUGH in the dataframe
                df.at[index, "ZIP CODE"] = zipcode
                df.at[index, "BOROUGH"] = borough

# %%
df[["BOROUGH", "ZIP CODE", "LONGITUDE", "LATITUDE"]]
# Out:
#        BOROUGH ZIP CODE  LONGITUDE   LATITUDE
# 0     BROOKLYN    11239 -73.890810  40.654440
# 1          NaN      NaN        NaN        NaN
# 2       QUEENS  11368.0 -73.853820  40.741104
# 3          NaN      NaN -74.133250  40.602543
# 4       QUEENS    11369 -73.893196  40.756897
# ...        ...      ...        ...        ...
# 6679     BRONX    10459 -73.881050  40.828430
# 6680  BROOKLYN    11205 -73.961880  40.699930
# 6681    QUEENS    11418 -73.839800  40.693657
# 6682  BROOKLYN  11204.0 -73.985700  40.620130
# 6683       NaN      NaN        NaN        NaN
#
# [6684 rows x 4 columns]

# %% [markdown]
# 7. Print the whole frequency table of CONTRIBUTING FACTOR VEHICLE 1. Convert lower cases to uppercases and check the frequencies again.

# %%
# display the entire frequency table
with pd.option_context('display.max_rows', None):
    print(df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts(dropna=False))

# checks how many unique variables there are
len(df["CONTRIBUTING FACTOR VEHICLE 1"].unique())
# Out:
# Driver Inattention/Distraction                           1631
# Unspecified                                              1567
# Failure to Yield Right-of-Way                             529
# Following Too Closely                                     418
# Passing or Lane Usage Improper                            320
# Unsafe Speed                                              261
# Passing Too Closely                                       246
# Backing Unsafely                                          206
# Traffic Control Disregarded                               185
# Turning Improperly                                        177
# Other Vehicular                                           174
# Driver Inexperience                                       141
# Unsafe Lane Changing                                      117
# Alcohol Involvement                                       109
# View Obstructed/Limited                                    69
# ...

# %%
# Convert lower cases to uppercases
df["CONTRIBUTING FACTOR VEHICLE 1"] = df["CONTRIBUTING FACTOR VEHICLE 1"].str.upper()

# Check the frequencies again
with pd.option_context('display.max_rows', None):
    print(df["CONTRIBUTING FACTOR VEHICLE 1"].value_counts(dropna=False))
    
len(df["CONTRIBUTING FACTOR VEHICLE 1"].unique())
# Out:
# DRIVER INATTENTION/DISTRACTION                           1631
# UNSPECIFIED                                              1567
# FAILURE TO YIELD RIGHT-OF-WAY                             529
# FOLLOWING TOO CLOSELY                                     418
# PASSING OR LANE USAGE IMPROPER                            320
# UNSAFE SPEED                                              261
# PASSING TOO CLOSELY                                       246
# BACKING UNSAFELY                                          206
# TRAFFIC CONTROL DISREGARDED                               185
# TURNING IMPROPERLY                                        177
# OTHER VEHICULAR                                           174
# DRIVER INEXPERIENCE                                       141
# UNSAFE LANE CHANGING                                      117
# ALCOHOL INVOLVEMENT                                       109
# VIEW OBSTRUCTED/LIMITED                                    69
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------
#
# 7. Provided an opportunity to meet the data provider, what suggestions do you have to make the data better based on your data exploration experience?

# %% [markdown]
# Suggestions:
#
# My first suggestion has to do with the LONGITUDE, LATITUDE, and LOCATION columns. Because the LOCATION column gives us both the LONGITUDE and LATITIUDE, there is no need for it. All the information about the LONGITUDE and LATITUDE are already exhausted in their respective columns.
#
# My second suggestion has to do with consistency. As seen with the LONGITUDE and LATITUDE data, instead leaving an entry blank, the data provider inputed 0's for both columns. Instead of doing this, I suggest that the data provider simply leaves the information blank when information is not know making it much easier to deal with cleaning data.
#
# My third suggestion is for the data providers to be more informative. For columns with number of people killed are those that are injured included? A small sentence describing this would be very helpful to those using the data.
#
# My fourth suggestion also has to do with consistency. Either make all variable names upper case or make them all lower case. Do not do a little of both. This leads to errors when coding.
